# %%
import pandas as pd

# %%
data = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# ### Membuat Data Frame

# %%
pd.DataFrame(data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### 1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce', downcast='integer')
data.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084000e+04
# mean      4.193338  4.441529e+05
# std       0.537431  2.927761e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.477550e+04
# max      19.000000  7.815831e+07

# %% [markdown]
# ###

# %% [markdown]
# ### 2.Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
data.select_dtypes(include=["int64","float64"]).head(10)
# Out:
#    Rating   Reviews
# 0     4.1     159.0
# 1     3.9     967.0
# 2     4.7   87510.0
# 3     4.5  215644.0
# 4     4.3     967.0
# 5     4.4     167.0
# 6     3.8     178.0
# 7     4.1   36815.0
# 8     4.4   13791.0
# 9     4.7     121.0

# %% [markdown]
# ### 3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
info = {}
info['Jumlah record'] = len(data)
info['Jumlah Atrribute'] = data.shape[1]
info['Nama Atributte'] = data.columns
info['Jumlah Atrribute bertipe angka'] = data.select_dtypes(include=['int', 'float']).shape[1]
pd.DataFrame.from_dict(info)
# Out:
#     Jumlah record  Jumlah Atrribute  Nama Atributte  \
# 0           10841                13             App
# 1           10841                13        Category
# 2           10841                13          Rating
# 3           10841                13         Reviews
# 4           10841                13            Size
# 5           10841                13        Installs
# 6           10841                13            Type
# 7           10841                13           Price
# 8           10841                13  Content Rating
# 9           10841                13          Genres
# 10          10841                13    Last Updated
# 11          10841                13     Current Ver
# 12          10841                13     Android Ver
#
#     Jumlah Atrribute bertipe angka
# 0                                2
# 1                                2
# 2                                2
# 3                                2
# 4                                2
# 5                                2
# 6                                2
# 7                                2
# 8                                2
# 9                                2
# 10                               2
# 11                               2
# 12                               2

# %% [markdown]
# ### 4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.

# %% [markdown]
# #### Dengan loc

# %%
data.loc[122:,'Reviews':]
# Out:
#         Reviews                Size     Installs  Type Price Content Rating  \
# 122     26834.0                 57M   1,000,000+  Free     0       Everyone
# 123       119.0                3.7M      50,000+  Free     0       Everyone
# 124      2277.0                 22M     500,000+  Free     0       Everyone
# 125      2280.0                 24M     500,000+  Free     0       Everyone
# 126       654.0                7.4M     100,000+  Free     0           Teen
# ...         ...                 ...          ...   ...   ...            ...
# 10836      38.0                 53M       5,000+  Free     0       Everyone
# 10837       4.0                3.6M         100+  Free     0       Everyone
# 10838       3.0                9.5M       1,000+  Free     0       Everyone
# 10839     114.0  Varies with device       1,000+  Free     0     Mature 17+
# 10840  398307.0                 19M  10,000,000+  Free     0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 122               Beauty     July 24, 2018                18.5
# 123               Beauty     July 23, 2018                 1.3
# 124               Beauty     July 12, 2018               1.1.0
# 125               Beauty      May 14, 2018               1.1.0
# 126               Beauty     July 17, 2018                1.15
# ...                  ...               ...                 ...
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 122            5.0 and up
# 123            4.1 and up
# 124          4.0.3 and up
# 125            4.0 and up
# 126            4.1 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10719 rows x 10 columns]

# %% [markdown]
# #### Dengan iloc

# %%
data.iloc[122:,4:]
# Out:
#                      Size     Installs  Type Price Content Rating  \
# 122                   57M   1,000,000+  Free     0       Everyone
# 123                  3.7M      50,000+  Free     0       Everyone
# 124                   22M     500,000+  Free     0       Everyone
# 125                   24M     500,000+  Free     0       Everyone
# 126                  7.4M     100,000+  Free     0           Teen
# ...                   ...          ...   ...   ...            ...
# 10836                 53M       5,000+  Free     0       Everyone
# 10837                3.6M         100+  Free     0       Everyone
# 10838                9.5M       1,000+  Free     0       Everyone
# 10839  Varies with device       1,000+  Free     0     Mature 17+
# 10840                 19M  10,000,000+  Free     0       Everyone
#
#                   Genres      Last Updated         Current Ver  \
# 122               Beauty     July 24, 2018                18.5
# 123               Beauty     July 23, 2018                 1.3
# 124               Beauty     July 12, 2018               1.1.0
# 125               Beauty      May 14, 2018               1.1.0
# 126               Beauty     July 17, 2018                1.15
# ...                  ...               ...                 ...
# 10836          Education     July 25, 2017                1.48
# 10837          Education      July 6, 2018                 1.0
# 10838            Medical  January 20, 2017                 1.0
# 10839  Books & Reference  January 19, 2015  Varies with device
# 10840          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 122            5.0 and up
# 123            4.1 and up
# 124          4.0.3 and up
# 125            4.0 and up
# 126            4.1 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10719 rows x 9 columns]

# %% [markdown]
# ### 5. Tampilkan jumlah label dari semua attribute yang bernilai object (contoh : Jenis Kelamin, Agama).

# %%
objek = data.select_dtypes(include='object')
jml_kol_objk = objek.nunique()
pd.DataFrame({'Jumlah Kolom Objek ': jml_kol_objk})
# Out:
#                 Jumlah Kolom Objek
# App                            9660
# Category                         34
# Size                            462
# Installs                         22
# Type                              3
# Price                            93
# Content Rating                    6
# Genres                          120
# Last Updated                   1378
# Current Ver                    2832
# Android Ver                      33
